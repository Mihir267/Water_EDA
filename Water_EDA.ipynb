# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Water_EDA/water.csv")

# %%
df.head()
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 1  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 2  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 3  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 4  WS_PPL_H-N: Proportion of population with no h...  _T: Total
#
#    TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                     2012                    30.777313
# 1                     2013                    28.224066
# 2                     2014                    25.679155
# 3                     2015                    23.142490
# 4                     2016                    20.614330
#
#    UNIT_MULTIPLIER:Unit multiplier UNIT_MEASURE:Unit of measure  \
# 0                              NaN                      PCNT: %
# 1                              NaN                      PCNT: %
# 2                              NaN                      PCNT: %
# 3                              NaN                      PCNT: %
# 4                              NaN                      PCNT: %
#
#    OBS_STATUS:Observation Status  OBS_CONF:Observation confidentaility  ...  \
# 0                            NaN                                   NaN  ...
# 1                            NaN                                   NaN  ...
# 2                            NaN                                   NaN  ...
# 3                            NaN                                   NaN  ...
# 4                            NaN                                   NaN  ...
#
#    WGTD_SAMPL_SIZE:Weighted Sample Size  OBS_FOOTNOTE:Observation footnote  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
#
#    SERIES_FOOTNOTE:Series footnote  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                         DATA_SOURCE:Data Source  \
# 0  WHO/UNICEF Joint Monitoring Programme (2023)
# 1  WHO/UNICEF Joint Monitoring Programme (2023)
# 2  WHO/UNICEF Joint Monitoring Programme (2023)
# 3  WHO/UNICEF Joint Monitoring Programme (2023)
# 4  WHO/UNICEF Joint Monitoring Programme (2023)
#
#    SOURCE_LINK:Citation of or link to the data source CUSTODIAN:Custodian  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#    TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    REF_PERIOD:Reference Period  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#    COVERAGE_TIME:The period of time for which data are provided  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AGE:Current age
# 0        _T: Total
# 1        _T: Total
# 2        _T: Total
# 3        _T: Total
# 4        _T: Total
#
# [5 rows x 22 columns]

# %%
df.size
# Out:
# 803418

# %%
df.shape
# Out:
# (36519, 22)

# %%
df.isnull()
# Out:
#        DATAFLOW  REF_AREA:Geographic area  INDICATOR:Indicator  SEX:Sex  \
# 0         False                     False                False    False
# 1         False                     False                False    False
# 2         False                     False                False    False
# 3         False                     False                False    False
# 4         False                     False                False    False
# ...         ...                       ...                  ...      ...
# 36514     False                     False                False    False
# 36515     False                     False                False    False
# 36516     False                     False                False    False
# 36517     False                     False                False    False
# 36518     False                     False                False    False
#
#        TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
# ...                        ...                          ...
# 36514                    False                        False
# 36515                    False                        False
# 36516                    False                        False
# 36517                    False                        False
# 36518                    False                        False
#
#        UNIT_MULTIPLIER:Unit multiplier  UNIT_MEASURE:Unit of measure  \
# 0                                 True                         False
# 1                                 True                         False
# 2                                 True                         False
# 3                                 True                         False
# 4                                 True                         False
# ...                                ...                           ...
# 36514                             True                         False
# 36515                             True                         False
# 36516                             True                         False
# 36517                             True                         False
# 36518                             True                         False
#
#        OBS_STATUS:Observation Status  OBS_CONF:Observation confidentaility  \
# 0                               True                                  True
# 1                               True                                  True
# 2                               True                                  True
# 3                               True                                  True
# 4                               True                                  True
# ...                              ...                                   ...
# 36514                           True                                  True
# 36515                           True                                  True
# 36516                           True                                  True
# 36517                           True                                  True
# 36518                           True                                  True
#
#        ...  WGTD_SAMPL_SIZE:Weighted Sample Size  \
# 0      ...                                  True
# 1      ...                                  True
# 2      ...                                  True
# 3      ...                                  True
# 4      ...                                  True
# ...    ...                                   ...
# 36514  ...                                  True
# 36515  ...                                  True
# 36516  ...                                  True
# 36517  ...                                  True
# 36518  ...                                  True
#
#        OBS_FOOTNOTE:Observation footnote  SERIES_FOOTNOTE:Series footnote  \
# 0                                   True                             True
# 1                                   True                             True
# 2                                   True                             True
# 3                                   True                             True
# 4                                   True                             True
# ...                                  ...                              ...
# 36514                               True                             True
# 36515                               True                             True
# 36516                               True                             True
# 36517                               True                             True
# 36518                               True                             True
#
#        DATA_SOURCE:Data Source  \
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 36514                    False
# 36515                    False
# 36516                    False
# 36517                    False
# 36518                    False
#
#        SOURCE_LINK:Citation of or link to the data source  \
# 0                                                   True
# 1                                                   True
# 2                                                   True
# 3                                                   True
# 4                                                   True
# ...                                                  ...
# 36514                                               True
# 36515                                               True
# 36516                                               True
# 36517                                               True
# 36518                                               True
#
#        CUSTODIAN:Custodian  \
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 36514                 True
# 36515                 True
# 36516                 True
# 36517                 True
# 36518                 True
#
#        TIME_PERIOD_METHOD:Time period activity related to when the data are collected  \
# 0                                                   True
# 1                                                   True
# 2                                                   True
# 3                                                   True
# 4                                                   True
# ...                                                  ...
# 36514                                               True
# 36515                                               True
# 36516                                               True
# 36517                                               True
# 36518                                               True
#
#        REF_PERIOD:Reference Period  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ...                            ...
# 36514                         True
# 36515                         True
# 36516                         True
# 36517                         True
# 36518                         True
#
#        COVERAGE_TIME:The period of time for which data are provided  \
# 0                                                   True
# 1                                                   True
# 2                                                   True
# 3                                                   True
# 4                                                   True
# ...                                                  ...
# 36514                                               True
# 36515                                               True
# 36516                                               True
# 36517                                               True
# 36518                                               True
#
#        AGE:Current age
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 36514            False
# 36515            False
# 36516            False
# 36517            False
# 36518            False
#
# [36519 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# DATAFLOW                                                                              0
# REF_AREA:Geographic area                                                              0
# INDICATOR:Indicator                                                                   0
# SEX:Sex                                                                               0
# TIME_PERIOD:Time period                                                               0
# OBS_VALUE:Observation Value                                                           0
# UNIT_MULTIPLIER:Unit multiplier                                                   36519
# UNIT_MEASURE:Unit of measure                                                          0
# OBS_STATUS:Observation Status                                                     36519
# OBS_CONF:Observation confidentaility                                              36519
# LOWER_BOUND:Lower Bound                                                           36519
# UPPER_BOUND:Upper Bound                                                           36519
# WGTD_SAMPL_SIZE:Weighted Sample Size                                              36519
# OBS_FOOTNOTE:Observation footnote                                                 36519
# SERIES_FOOTNOTE:Series footnote                                                   36519
# DATA_SOURCE:Data Source                                                               0
# SOURCE_LINK:Citation of or link to the data source                                36519
# CUSTODIAN:Custodian                                                               36519
# TIME_PERIOD_METHOD:Time period activity related to when the data are collected    36519
# REF_PERIOD:Reference Period                                                       36519
# COVERAGE_TIME:The period of time for which data are provided                      36519
# AGE:Current age                                                                       0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 474747

# %%
df = df.dropna(axis=1, how='all')

# %%
df.head()
# Out:
#                                             DATAFLOW REF_AREA:Geographic area  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...         AFG: Afghanistan
#
#                                  INDICATOR:Indicator    SEX:Sex  \
# 0  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 1  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 2  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 3  WS_PPL_H-N: Proportion of population with no h...  _T: Total
# 4  WS_PPL_H-N: Proportion of population with no h...  _T: Total
#
#    TIME_PERIOD:Time period  OBS_VALUE:Observation Value  \
# 0                     2012                    30.777313
# 1                     2013                    28.224066
# 2                     2014                    25.679155
# 3                     2015                    23.142490
# 4                     2016                    20.614330
#
#   UNIT_MEASURE:Unit of measure                       DATA_SOURCE:Data Source  \
# 0                      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 1                      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 2                      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 3                      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 4                      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
#
#   AGE:Current age
# 0       _T: Total
# 1       _T: Total
# 2       _T: Total
# 3       _T: Total
# 4       _T: Total

# %%
df.isnull().sum()
# Out:
# DATAFLOW                        0
# REF_AREA:Geographic area        0
# INDICATOR:Indicator             0
# SEX:Sex                         0
# TIME_PERIOD:Time period         0
# OBS_VALUE:Observation Value     0
# UNIT_MEASURE:Unit of measure    0
# DATA_SOURCE:Data Source         0
# AGE:Current age                 0
# dtype: int64

# %%
df = df.rename(columns= {
    'REF_AREA:Geographic area':'REF_AREA',
    'INDICATOR:Indicator':'INDICATOR',
    'TIME_PERIOD:Time period':'TIME_PERIOD',
    'OBS_VALUE:Observation Value':'OBS_VALUE',
    'UNIT_MEASURE:Unit of measure':'UNIT_MEASURE',
    'DATA_SOURCE:Data Source':'DATA_SOURCE',
    'AGE:Current age':'AGE'



})

# %%
df.head()
# Out:
#                                             DATAFLOW          REF_AREA  \
# 0  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...  AFG: Afghanistan
# 1  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...  AFG: Afghanistan
# 2  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...  AFG: Afghanistan
# 3  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...  AFG: Afghanistan
# 4  UNICEF:GLOBAL_DATAFLOW(1.0): Cross-sector indi...  AFG: Afghanistan
#
#                                            INDICATOR    SEX:Sex  TIME_PERIOD  \
# 0  WS_PPL_H-N: Proportion of population with no h...  _T: Total         2012
# 1  WS_PPL_H-N: Proportion of population with no h...  _T: Total         2013
# 2  WS_PPL_H-N: Proportion of population with no h...  _T: Total         2014
# 3  WS_PPL_H-N: Proportion of population with no h...  _T: Total         2015
# 4  WS_PPL_H-N: Proportion of population with no h...  _T: Total         2016
#
#    OBS_VALUE UNIT_MEASURE                                   DATA_SOURCE  \
# 0  30.777313      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 1  28.224066      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 2  25.679155      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 3  23.142490      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
# 4  20.614330      PCNT: %  WHO/UNICEF Joint Monitoring Programme (2023)
#
#          AGE
# 0  _T: Total
# 1  _T: Total
# 2  _T: Total
# 3  _T: Total
# 4  _T: Total

# %%
df.isnull().sum()
# Out:
# DATAFLOW        0
# REF_AREA        0
# INDICATOR       0
# SEX:Sex         0
# TIME_PERIOD     0
# OBS_VALUE       0
# UNIT_MEASURE    0
# DATA_SOURCE     0
# AGE             0
# dtype: int64

# %%
df.describe()
# Out:
#         TIME_PERIOD     OBS_VALUE
# count  36519.000000  36519.000000
# mean    2016.848243     39.625292
# std        3.091017     38.467088
# min     2012.000000      0.000000
# 25%     2014.000000      2.294425
# 50%     2017.000000     26.165874
# 75%     2019.000000     80.827447
# max     2022.000000    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36519 entries, 0 to 36518
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATAFLOW      36519 non-null  object
#  1   REF_AREA      36519 non-null  object
#  2   INDICATOR     36519 non-null  object
#  3   SEX:Sex       36519 non-null  object
#  4   TIME_PERIOD   36519 non-null  int64
#  5   OBS_VALUE     36519 non-null  float64
#  6   UNIT_MEASURE  36519 non-null  object
#  7   DATA_SOURCE   36519 non-null  object
#  8   AGE           36519 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.5+ MB

# %%
df.dtypes
# Out:
# DATAFLOW         object
# REF_AREA         object
# INDICATOR        object
# SEX:Sex          object
# TIME_PERIOD       int64
# OBS_VALUE       float64
# UNIT_MEASURE     object
# DATA_SOURCE      object
# AGE              object
# dtype: object

# %%
plt.figure(figsize=(8,10))

sns.histplot(data=df, x='TIME_PERIOD', bins=30, kde=True)
plt.xlabel("Time_Period")
plt.ylabel("Count")
plt.title("Histogram of Time_Period")
plt.show()

# %%
sns.histplot(data=df, x='OBS_VALUE', bins=30, kde=True)
plt.xlabel("Observation Values")
plt.ylabel("Counts")
plt.title("Histogram of Observation Values")

plt.show()

# %%
df['REF_AREA'].value_counts()
# Out:
# REF_AREA
# NGA: Nigeria                                           182
# UNSDG_SUBSAHARANAFRICA: Sub-Saharan Africa             182
# UNSDG_LLDC: Landlocked developing countries (LLDCs)    182
# CRI: Costa Rica                                        182
# WB_LI: World Bank (low income)                         182
#                                                       ...
# ARG: Argentina                                          43
# SXM: Sint Maarten                                       42
# CUW: Curaçao                                            42
# ABW: Aruba                                              35
# HRV: Croatia                                             8
# Name: count, Length: 279, dtype: int64

# %%
value_counts = df['REF_AREA'].value_counts()

plt.figure(figsize=(10,6))

sns.histplot(data=df, x=value_counts, bins=30, kde=True)
plt.xlabel("Value_counts")
plt.ylabel("Frequency")
plt.title("Histogram of geographical area")
plt.show()
